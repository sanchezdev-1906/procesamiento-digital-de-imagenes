# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def solarizar(imagen, umbral):
    imagen_solarizada = np.where(imagen<umbral,imagen,255-imagen)
    return imagen_solarizada


img_gray = cv2.imread("imagen.png")
img_gris = cv2.cvtColor(img_gray,cv2.COLOR_BGR2GRAY)
nivel = 1
newim = solarizar(img_gray,nivel)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img_gray,cv2.COLOR_BGR2RGB))
plt.subplot(1,2,2)
plt.imshow(newim, cmap='gray')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def posterizar(imagen, nivel):
    factor = 255/nivel
    imagen_post = np.round(imagen/(factor)*factor)
    return imagen_post


imagen = cv2.imread("imagen.png")
img_gris = cv2.cvtColor(imagen,cv2.COLOR_BGR2GRAY)

nivel = 200
newim = posterizar(imagen,nivel)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB))
plt.subplot(1,2,2)
plt.imshow(newim, cmap='gray')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..241.0].

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def falso_color(img_gray):
    scale_img = cv2.normalize(img_gray,None,0,255,cv2.NORM_MINMAX)
    apcol = cv2.applyColorMap(scale_img, cv2.COLORMAP_DEEPGREEN)
    return apcol


imagen = cv2.imread("imagen.png",0)
newim = falso_color(imagen)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB))
plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(newim,cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math

def falso_color(img_gray, colormap):
    scale_img = cv2.normalize(img_gray, None, 0, 255, cv2.NORM_MINMAX)
    return cv2.applyColorMap(scale_img, colormap)

imagen = cv2.imread("imagen.png", 0)

colormaps = [
    {"name": "COLORMAP_AUTUMN", "value": cv2.COLORMAP_AUTUMN},
    {"name": "COLORMAP_BONE", "value": cv2.COLORMAP_BONE},
    {"name": "COLORMAP_JET", "value": cv2.COLORMAP_JET},
    {"name": "COLORMAP_WINTER", "value": cv2.COLORMAP_WINTER},
    {"name": "COLORMAP_RAINBOW", "value": cv2.COLORMAP_RAINBOW},
    {"name": "COLORMAP_OCEAN", "value": cv2.COLORMAP_OCEAN},
    {"name": "COLORMAP_SUMMER", "value": cv2.COLORMAP_SUMMER},
    {"name": "COLORMAP_SPRING", "value": cv2.COLORMAP_SPRING},
    {"name": "COLORMAP_COOL", "value": cv2.COLORMAP_COOL},
    {"name": "COLORMAP_HSV", "value": cv2.COLORMAP_HSV},
    {"name": "COLORMAP_PINK", "value": cv2.COLORMAP_PINK},
    {"name": "COLORMAP_HOT", "value": cv2.COLORMAP_HOT},
    {"name": "COLORMAP_PARULA", "value": cv2.COLORMAP_PARULA},
    {"name": "COLORMAP_MAGMA", "value": cv2.COLORMAP_MAGMA},
    {"name": "COLORMAP_INFERNO", "value": cv2.COLORMAP_INFERNO},
    {"name": "COLORMAP_PLASMA", "value": cv2.COLORMAP_PLASMA},
    {"name": "COLORMAP_VIRIDIS", "value": cv2.COLORMAP_VIRIDIS},
    {"name": "COLORMAP_CIVIDIS", "value": cv2.COLORMAP_CIVIDIS},
    {"name": "COLORMAP_TWILIGHT", "value": cv2.COLORMAP_TWILIGHT},
    {"name": "COLORMAP_TWILIGHT_SHIFTED", "value": cv2.COLORMAP_TWILIGHT_SHIFTED},
    {"name": "COLORMAP_TURBO", "value": cv2.COLORMAP_TURBO},
    {"name": "COLORMAP_DEEPGREEN", "value": cv2.COLORMAP_DEEPGREEN}
]


l = len(colormaps)
cols = 4  
rows = math.ceil(l / cols)  

plt.figure(figsize=(cols * 3, rows * 3))  

for i in range(l):
    newim = falso_color(imagen, colormaps[i]["value"])
    plt.subplot(rows, cols, i + 1)  
    plt.imshow(cv2.cvtColor(newim, cv2.COLOR_BGR2RGB))
    plt.title(colormaps[i]["name"]) 

plt.show()
