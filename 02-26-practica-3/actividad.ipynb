# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

img_bgr = cv2.imread("imagen.jpg",cv2.IMREAD_GRAYSCALE)
# img_gray = cv2.cvtColor(img_bgr,cv2.COLOR_BGR2GRAY)
img_bayer = cv2.cvtColor(img_bgr,cv2.COLOR_BAYER_BG2RGB)
fig,axs = plt.subplots(1,4,figsize=(20,5))
axs[0].imshow(img_bgr)
# axs[1].imshow(img_gray)
axs[2].imshow(img_bayer)
