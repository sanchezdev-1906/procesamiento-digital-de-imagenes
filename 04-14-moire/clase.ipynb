# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

imgo1 = cv2.imread("distorsion-1.jpg")
imgo2 = cv2.imread("distorsion-2.jpg")
imgo3 = cv2.imread("distorsion-3.jpg")
img1 = cv2.cvtColor(imgo1,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(imgo2,cv2.COLOR_BGR2RGB)
img3 = cv2.cvtColor(imgo3,cv2.COLOR_BGR2RGB)

maskDiagonal = np.array([
    [1,0,1],
    [0,-1,0],
    [1,0,1]
    ],dtype=np.float32
)/3

final1 = cv2.GaussianBlur(img1,(11,11),0)
# final1 = cv2.GaussianBlur(img1,(9,9),0)
# final1 = cv2.filter2D(final1,-1,maskDiagonal)
final2 = cv2.GaussianBlur(img2,(9,9),0)
final3 = cv2.GaussianBlur(img3,(9,9),0)

fig,axs = plt.subplots(3,2,figsize=(20,20))

axs[0][0].imshow(img1)
axs[0][1].imshow(final1)
axs[1][0].imshow(img2)
axs[1][1].imshow(final2)
axs[2][0].imshow(img3)
axs[2][1].imshow(final3)
